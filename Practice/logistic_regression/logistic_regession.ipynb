# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
from matplotlib import pyplot as plt
import math
import numpy as np
# Out:
# C:\Users\brean\AppData\Local\Temp\ipykernel_35444\2876505151.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Actual Solution

# %%
df = pd.read_csv("./CollegePlacement.csv")
df['Placement'] = pd.factorize(df['Placement'])[0]
df['Internship_Experience'] = pd.factorize(df['Internship_Experience'])[0]


X = df.drop(["Placement", "College_ID"], axis = 1)

Y = df["Placement"]


logreg = LogisticRegression(random_state=16,  max_iter=1000, penalty=None)

model = logreg.fit(X, Y)
coef_df = {col : coef for col, coef in zip(list(X.columns), model.coef_[0])}
# print(coef_df)
# print(X.columns)
print(f"coefficent: {coef_df}\nintercept: {model.intercept_}")
# Out:
# coefficent: {'IQ': 0.1088480546249706, 'Prev_Sem_Result': 0.20739706715685027, 'CGPA': 1.0503634055233622, 'Academic_Performance': -0.006580066792577768, 'Internship_Experience': 0.03812121633450414, 'Extra_Curricular_Score': -0.01601374794054621, 'Communication_Skills': 0.6480372982054753, 'Projects_Completed': 0.6793231551407346}
# intercept: [-29.18952604]

# %% [markdown]
# # Numerical Solution
#
# $ g(B^Tx)= \frac{1}{1+e^{-(B^Tx)}}$
#
# $B^Tx=B_0x_0+B_1x_1+...+B_nx_n$
#
# $x_0=1$
#
#
# $$
# y = \begin{cases}
#     \text{1 if} & B^Tx\text{ ≥ 0} \\
#     \text{0 if} & B^Tx\text{< 0} \\
# \end{cases}
# $$

# %%
df = pd.read_csv("./CollegePlacement.csv")
# df = pd.read_csv("./college_partial.csv")

df['Placement'] = pd.factorize(df['Placement'])[0]
df['Internship_Experience'] = pd.factorize(df['Internship_Experience'])[0]
df
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0       CLG0030  107             6.61  6.28                     8
# 1       CLG0061   97             5.52  5.37                     8
# 2       CLG0036  109             5.36  5.83                     9
# 3       CLG0055  122             5.47  5.75                     6
# 4       CLG0004   96             7.91  7.69                     7
# ...         ...  ...              ...   ...                   ...
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#       Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                         0                       8                     8
# 1                         0                       7                     8
# 2                         0                       3                     1
# 3                         1                       1                     6
# 4                         0                       8                    10
# ...                     ...                     ...                   ...
# 9995                      0                       1                     8
# 9996                      0                       0                     7
# 9997                      1                       3                     9
# 9998                      0                       7                     5
# 9999                      0                       3                     5
#
#       Projects_Completed  Placement
# 0                      4          0
# 1                      0          0
# 2                      1          0
# 3                      1          0
# 4                      2          0
# ...                  ...        ...
# 9995                   0          1
# 9996                   2          0
# 9997                   5          0
# 9998                   1          0
# 9999                   5          0
#
# [10000 rows x 10 columns]

# %% [markdown]
# X contains our coefficents (B)

# %%
X = df.drop(["Placement", "College_ID"], axis = 1)
X.insert(0, "intercept", [1] * X.shape[0])
Y = df["Placement"].to_numpy()

X
# Out:
#       intercept   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0             1  107             6.61  6.28                     8
# 1             1   97             5.52  5.37                     8
# 2             1  109             5.36  5.83                     9
# 3             1  122             5.47  5.75                     6
# 4             1   96             7.91  7.69                     7
# ...         ...  ...              ...   ...                   ...
# 9995          1  119             8.41  8.29                     4
# 9996          1   70             9.25  9.34                     7
# 9997          1   89             6.08  6.25                     3
# 9998          1  107             8.77  8.92                     3
# 9999          1  109             9.41  9.77                     8
#
#       Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                         0                       8                     8
# 1                         0                       7                     8
# 2                         0                       3                     1
# 3                         1                       1                     6
# 4                         0                       8                    10
# ...                     ...                     ...                   ...
# 9995                      0                       1                     8
# 9996                      0                       0                     7
# 9997                      1                       3                     9
# 9998                      0                       7                     5
# 9999                      0                       3                     5
#
#       Projects_Completed
# 0                      4
# 1                      0
# 2                      1
# 3                      1
# 4                      2
# ...                  ...
# 9995                   0
# 9996                   2
# 9997                   5
# 9998                   1
# 9999                   5
#
# [10000 rows x 9 columns]

# %% [markdown]
# $ g(B^Tx)= \frac{1}{1+e^{-(B^Tx)}}$
#
# $B^Tx=B_0x_0+B_1x_1+...+B_nx_n$
#
# $x_0=1$
#
#
# $$
# y = \begin{cases}
#     \text{1 if} & B^Tx\text{ ≥ 0} \\
#     \text{0 if} & B^Tx\text{< 0} \\
# \end{cases}
# $$
#
# ## Cost Function
#
# $i$ is a row $j$ is a column
#
# $ J(B) = \frac{1}{m} \sum [y_i ln(\frac{1}{1+e^{-(B^Tx)}}) + (1-y_i)ln(\frac{1}{1+e^{-(B^Tx)}})]$
#
# $ B_j := B_j-α(\frac{∂J(B)}{∂B_j}) $
#
# $ \frac{∂J(B)}{∂B_j} = \frac{1}{m} \sum [(\frac{1}{1+e^{-(B^Tx)}}) - y_i]x_{j,i}$

# %%
LEARNING_RATE = 0.1
EPOCHS = 100


cols = list(X.columns)
# cols[0] = "intercept"
array_x = X.to_numpy()
B_array = np.zeros( X.shape[1]) 


def compute_sigmoid(z):
    return np.where(
            z >= 0, # condition
            1 / (1 + np.exp(-z)), # For positive values
            np.exp(z) / (1 + np.exp(z)) # For negative values
    )


for epoch in range(EPOCHS):
    
    
    ## gradient descent
    # z_values = np.sum(array_x * B_array, axis = 1) ## alt: 
    z_values = array_x @ B_array
    sigmoids = compute_sigmoid(z_values)

    # current_b_partials = np.sum( ( array_x * np.array(sigmoids - Y)[:, np.newaxis] / len(Y) ) , axis = 0 )  ## alt: 
    current_b_partials = np.sum( (sigmoids - Y)[:,np.newaxis] * array_x, axis = 0 ) / Y.shape[0]

    ## update weights
    B_array -= LEARNING_RATE * current_b_partials

    ## compute error
    z_values = np.sum(array_x * B_array, axis = 1) ## alt: array_x @ B_array

    sigmoids = compute_sigmoid(z_values)
    # eps=1e-15
    # sigmoids = np.clip(sigmoids, eps, 1 - eps)
    error = sum( ( Y * np.log(sigmoids) ) + ( (1 - Y) * np.log(1 - sigmoids) ) ) * (-1/len(Y))

    vecb = {col: b for col, b in zip(cols, B_array)}
    print(f"------------------------------------------Epoch: {epoch + 1}------------------------------------------")
    print(f"ERROR: {error}\ncoefficents: {vecb}")

------------------------------------
# ERROR: nan
# coefficents: {'intercept': -0.1546005670405577, 'IQ': -5.772802457995645, 'Prev_Sem_Result': -0.13801830518452474, 'CGPA': -0.10928220694494861, 'Academic_Performance': -0.9531613474923766, 'Internship_Experience': -0.06766035782189272, 'Extra_Curricular_Score': -0.8019360725395401, 'Communication_Skills': 1.2323245946190517, 'Projects_Completed': 0.44438845743170613}
# ------------------------------------------Epoch: 61------------------------------------------
# ERROR: 71.07096986753294
# coefficents: {'intercept': -0.1380105670405577, 'IQ': -3.962472457995645, 'Prev_Sem_Result': 0.004115194815475287, 'CGPA': 0.03326709305505138, 'Academic_Performance': -0.8627413474923766, 'Internship_Experience': -0.06119035782189272, 'Extra_Curricular_Score': -0.7200260725395401, 'Communication_Skills': 1.3594645946190518, 'Projects_Completed': 0.49996845743170615}
# ------------------------------------------Epoch: 62------------------------------------------
# ERROR: 37.54824213600547
# coefficents: {'intercept': -0.1214205670405577, 'IQ': -2.1521424579956445, 'Prev_Sem_Result': 0.1462486948154753, 'CGPA': 0.17581639305505137, 'Academic_Performance': -0.7723213474923767, 'Internship_Experience': -0.05472035782189272, 'Extra_Curricular_Score': -0.6381160725395401, 'Communication_Skills': 1.4866045946190518, 'Projects_Completed': 0.5555484574317061}
# C:\Users\brean\AppData\Local\Temp\ipykernel_35444\2895310541.py:39: RuntimeWarning: divide by zero encountered in log
#   error = sum( ( Y * np.log(sigmoids) ) + ( (1 - Y) * np.log(1 - sigmoids) ) ) * (-1/len(Y))
# C:\Users\brean\AppData\Local\Temp\ipykernel_35444\2895310541.py:39: RuntimeWarning: invalid value encountered in multiply
#   error = sum( ( Y * np.log(sigmoids) ) + ( (1 - Y) * np.log(1 - sigmoids) ) ) * (-1/len(Y))
# C:\Users\brean\AppData\Local\Temp\ipykernel_35444\2895310541.py:14: RuntimeWarning: overflow encountered in exp
#   1 / (1 + np.exp(-z)), # For positive values
# ------------------------------------------Epoch: 63------------------------------------------
# ERROR: 4.025906423479486
# coefficents: {'intercept': -0.10483056704055771, 'IQ': -0.3418124579956443, 'Prev_Sem_Result': 0.28838219481547533, 'CGPA': 0.31836569305505136, 'Academic_Performance': -0.6819013474923767, 'Internship_Experience': -0.048250357821892714, 'Extra_Curricular_Score': -0.55620607253954, 'Communication_Skills': 1.6137445946190518, 'Projects_Completed': 0.6111284574317061}
# ------------------------------------------Epoch: 64------------------------------------------
# ERROR: nan
# coefficents: {'intercept': -0.08826972041317514, 'IQ': 1.4667875297503306, 'Prev_Sem_Result': 0.43029927014635316, 'CGPA': 0.4606986751376385, 'Academic_Performance': -0.5915495150542218, 'Internship_Experience': -0.0417971689290341, 'Extra_Curricular_Score': -0.47434393373421524, 'Communication_Skills': 1.7406030660570964, 'Projects_Completed': 0.6666223580635872}
# ------------------------------------------Epoch: 65------------------------------------------
# ERROR: nan
# coefficents: {'intercept': -0
# ERROR: 36.82316307581642
# coefficents: {'intercept': -0.13895972041317517, 'IQ': -2.1346024702496678, 'Prev_Sem_Result': 0.20236617014635327, 'CGPA': 0.2371665751376384, 'Academic_Performance': -0.8870495150542224, 'Internship_Experience': -0.06284716892903408, 'Extra_Curricular_Score': -0.731333933734215, 'Communication_Skills': 1.7725030660570964, 'Projects_Completed': 0.6641623580635868}
# ------------------------------------------Epoch: 74------------------------------------------
# ERROR: 3.306108577268965
# coefficents: {'intercept': -0.12236972041317518, 'IQ': -0.32427247024966754, 'Prev_Sem_Result': 0.3444996701463533, 'CGPA': 0.3797158751376384, 'Academic_Performance': -0.7966295150542224, 'Internship_Experience': -0.05637716892903408, 'Extra_Curricular_Score': -0.6494239337342149, 'Communication_Skills': 1.8996430660570964, 'Projects_Completed': 0.7197423580635868}
# ------------------------------------------Epoch: 75------------------------------------------
# ERROR: nan
# coefficents: {'intercept': -0.10605706385036398, 'IQ': 1.4677341100791101, 'Prev_Sem_Result': 0.4844422735968358, 'CGPA': 0.5200700025760697, 'Academic_Performance': -0.7069593318392752, 'Internship_Experience': -0.0500332725054548, 'Extra_Curricular_Score': -0.5682311147867504, 'Communication_Skills': 2.0241890716576623, 'Projects_Completed': 0.7743938571010924}
# ------------------------------------------Epoch: 76------------------------------------------
# ERROR: nan
# coefficents: {'intercept': -0.189467063850364, 'IQ': -6.66911588992089, 'Prev_Sem_Result': -0.12699152640316425, 'CGPA': -0.0906185974239303, 'Academic_Performance': -1.1711793318392751, 'Internship_Experience': -0.0832032725054548, 'Extra_Curricular_Score': -0.9834111147867504, 'Communication_Skills': 1.5951490716576622, 'Projects_Completed': 0.5786338571010924}
# ------------------------------------------Epoch: 77------------------------------------------
# ERROR: nan
# coefficents: {'intercept': -0.172877063850364, 'IQ': -4.85878588992089, 'Prev_Sem_Result': 0.015141973596835778, 'CGPA': 0.05193070257606969, 'Academic_Performance': -1.0807593318392752, 'Internship_Experience': -0.0767332725054548, 'Extra_Curricular_Score': -0.9015011147867503, 'Communication_Skills': 1.7222890716576622, 'Projects_Completed': 0.6342138571010923}
# ------------------------------------------Epoch: 78------------------------------------------
# ERROR: 53.548854910540435
# coefficents: {'intercept': -0.156287063850364, 'IQ': -3.0484558899208896, 'Prev_Sem_Result': 0.1572754735968358, 'CGPA': 0.19448000257606968, 'Academic_Performance': -0.9903393318392752, 'Internship_Experience': -0.07026327250545479, 'Extra_Curricular_Score': -0.8195911147867503, 'Communication_Skills': 1.8494290716576622, 'Projects_Completed': 0.6897938571010923}
# ------------------------------------------Epoch: 79------------------------------------------
# ERROR: 20.02612717901296
# coefficents: {'intercept': -0.139697063850364, 'IQ': -1.2381258899208893, 'Prev_Sem_Result': 0.2994089735968358, 'CGPA': 0.33702930257606967, 'Academic_Performance': -0.8999193318392753, 'Internship_Experience': -0.06379327250545479, 'Extra_Curricular_Score': -0.7376811147867502, 'Communication_Skills': 1.9765690716576623, 'Projects_Completed': 0.7453738571010923}
# ------------------------------------------Epoch: 80------------------------------------------
# ERROR: nan
# coefficents: {'intercept': -0
# ------------------------------------------Epoch: 96------------------------------------------
# ERROR: 3.4647729859288567
# coefficents: {'intercept': -0.15864009432254744, 'IQ': -0.3745051103359691, 'Prev_Sem_Result': 0.4471356353949527, 'CGPA': 0.49282131396113105, 'Academic_Performance': -1.0297563299156727, 'Internship_Experience': -0.0731491504868666, 'Extra_Curricular_Score': -0.8390622103710024, 'Communication_Skills': 2.460386635452401, 'Projects_Completed': 0.9329202344992612}
# ------------------------------------------Epoch: 97------------------------------------------
# ERROR: nan
# coefficents: {'intercept': -0.1427803245792951, 'IQ': 1.384463346066958, 'Prev_Sem_Result': 0.5833832787062356, 'CGPA': 0.6294911089156261, 'Academic_Performance': -0.9415608592785284, 'Internship_Experience': -0.06700238656960937, 'Extra_Curricular_Score': -0.7591140180434447, 'Communication_Skills': 2.5807357141396308, 'Projects_Completed': 0.9860166430837617}
# ------------------------------------------Epoch: 98------------------------------------------
# ERROR: nan
# coefficents: {'intercept': -0.2261903245792951, 'IQ': -6.752386653933042, 'Prev_Sem_Result': -0.028050521293764397, 'CGPA': 0.01880250891562607, 'Academic_Performance': -1.4057808592785284, 'Internship_Experience': -0.10017238656960936, 'Extra_Curricular_Score': -1.1742940180434447, 'Communication_Skills': 2.1516957141396307, 'Projects_Completed': 0.7902566430837616}
# ------------------------------------------Epoch: 99------------------------------------------
# ERROR: nan
# coefficents: {'intercept': -0.20960032457929512, 'IQ': -4.942056653933042, 'Prev_Sem_Result': 0.11408297870623563, 'CGPA': 0.16135180891562606, 'Academic_Performance': -1.3153608592785284, 'Internship_Experience': -0.09370238656960936, 'Extra_Curricular_Score': -1.0923840180434448, 'Communication_Skills': 2.2788357141396305, 'Projects_Completed': 0.8458366430837616}
# ------------------------------------------Epoch: 100------------------------------------------
# ERROR: 54.31017903014741
# coefficents: {'intercept': -0.19301032457929512, 'IQ': -3.1317266539330415, 'Prev_Sem_Result': 0.25621647870623565, 'CGPA': 0.30390110891562605, 'Academic_Performance': -1.2249408592785285, 'Internship_Experience': -0.08723238656960935, 'Extra_Curricular_Score': -1.0104740180434448, 'Communication_Skills': 2.4059757141396303, 'Projects_Completed': 0.9014166430837616}

# %%
Y = df["Placement"].to_numpy()
array_x = X.to_numpy()

# %%
LEARNING_RATE = 0.01
EPOCHS = 10000

b_vector = np.zeros(array_x.shape[1]) ## initilize intercept and coefficents as 0
cols = list(X.columns)


def compute_sigmoid(B: np.ndarray, X: np.ndarray):

    # return 1 / (1 + np.exp(-np.dot(X, B))) ## ALT METHOD: np.dot(X, B) computes the dot product between each row of X and B
    # return 1/(  1 + np.exp( - X @ B )  ) ## X @ B computes the dot product between each row of X and B
    return np.where(
            X @ B >= 0, # condition
            1 / (1 + np.exp(-X @ B)), # For positive values
            np.exp(X @ B) / (1 + np.exp(X @ B)) # For negative values
    )


def compute_cost(B: np.ndarray, X: np.ndarray, Y: np.ndarray):
    num_rows = Y.shape[0]
    sigmoid = compute_sigmoid(B, X)

    return np.sum((Y * np.log(sigmoid)) + (1 - Y) * np.log(sigmoid)) / -num_rows

def partial_derivative(B: np.ndarray, X: np.ndarray, Y: np.ndarray):
    num_rows = Y.shape[0]
    sigmoid = compute_sigmoid(B, X)

    # return (1 / num_rows) * np.dot(X.T, (sigmoid - Y)) ## ALT METHOD
    
    ## (sigmoid - Y)[:,np.newaxis] changes its shape from (n,) to (n, 1)
    return np.sum( (sigmoid - Y)[:,np.newaxis] * X, axis = 0 ) / num_rows


for epoch in range(EPOCHS):

    cost = compute_cost(b_vector, array_x, Y)
    
    b_vector -= LEARNING_RATE * partial_derivative(b_vector, array_x, Y)

    b_dict = {col : b for col, b in zip(cols, b_vector)}

    if epoch % 100 == 0 or epoch+1 == EPOCHS:
        print(f"------------------------------------epoch: {epoch}------------------------------------")
        print(f"\t\t\t\tcost: {cost}\nb_dict: {b_dict}")


print("final values: ")
for key, value in b_dict.items(): print(f"{key}: {round(value,8)}")
# Out:
# ------------------------------------epoch: 0------------------------------------
# 				cost: 0.6931471805599453
# b_dict: {'intercept': -0.0033410000000000002, 'IQ': -0.316326, 'Prev_Sem_Result': -0.023465015000000002, 'CGPA': -0.023406965000000005, 'Academic_Performance': -0.018690000000000002, 'Internship_Experience': -0.001335, 'Extra_Curricular_Score': -0.0166635, 'Communication_Skills': -0.015095, 'Projects_Completed': -0.007009}
# ------------------------------------epoch: 100------------------------------------
# 				cost: 2.9878329471667078
# b_dict: {'intercept': -0.015769791650236058, 'IQ': 0.06864728701853134, 'Prev_Sem_Result': 0.05214419267598205, 'CGPA': 0.05693847091476238, 'Academic_Performance': -0.09502505554374435, 'Internship_Experience': -0.00719451431653022, 'Extra_Curricular_Score': -0.07623755850856173, 'Communication_Skills': 0.2444962286739376, 'Projects_Completed': 0.09786997076842936}
# ------------------------------------epoch: 200------------------------------------
# 				cost: 0.5747183012120715
# b_dict: {'intercept': -0.038300981880326095, 'IQ': -0.4647942382480097, 'Prev_Sem_Result': 0.04683255816218569, 'CGPA': 0.05637203085426874, 'Academic_Performance': -0.20418096463337754, 'Internship_Experience': -0.016658067253214115, 'Extra_Curricular_Score': -0.1653097213381798, 'Communication_Skills': 0.39392312685681297, 'Projects_Completed': 0.16980449733215117}
# ------------------------------------epoch: 300------------------------------------
# 				cost: 14.368757156901303
# b_dict: {'intercept': -0.05073485954537551, 'IQ': 0.006800599523915457, 'Prev_Sem_Result': 0.11648414790177301, 'CGPA': 0.13070555877478202, 'Academic_Performance': -0.25193170707623697, 'Internship_Experience': -0.021988374829950526, 'Extra_Curricular_Score': -0.1996011156609434, 'Communication_Skills': 0.5878143815972164, 'Projects_Completed': 0.2648189913076232}
# ------------------------------------epoch: 400------------------------------------
# 				cost: 19.78406272505717
# b_dict: {'intercept': -0.06916151904901367, 'IQ': -0.05335934516860186, 'Prev_Sem_Result': 0.1368014039605308, 'CGPA': 0.15571923379380848, 'Academic_Performance': -0.31397278773970605, 'Internship_Experience': -0.02938119101635519, 'Extra_Curricular_Score': -0.2474203409495004, 'Communication_Skills': 0.7052054208907371, 'Projects_Completed': 0.33774738274684696}
# ------------------------------------epoch: 500------------------------------------
# 				cost: 29.7617934806943
# b_dict: {'intercept': -0.08852101926509916, 'IQ': -0.1566502291721014, 'Prev_Sem_Result': 0.14666482037453624, 'CGPA': 0.1702386383069151, 'Academic_Performance': -0.36435822678134877, 'Internship_Experience': -0.03685966972356624, 'Extra_Curricular_Score': -0.28516740555674425, 'Communication_Skills': 0.7849069197966657, 'Projects_Completed': 0.40130471467981893}
# ------------------------------------epoch: 600------------------------------------
# 				cost: 0.19204885434618688
# b_dict: {'intercept': -0.11152157974008446, 'IQ': -0.7058572300413937, 'Prev_Sem_Result': 0.13265745623658393, 'CGPA': 0.16088551178516197, 'Academic_Performance': -0.45181103930691857, 'Internship_Experience': -0.0459583923694893, 'Extra_Curricular_Score': -0.3561527411884979, 'Communication_Skills': 0.8823132820562863, 'Projects_Completed': 0.46102647041556377}
# ------------------------------------epoch: 700------------------------------------
# 				cost: 42.86504042944997
# b_dict: {'intercept': -0.12566224701196052, 'IQ': -0.2984828381237679, 'Prev_Sem_Result': 0.18165660024705294, 'CGPA': 0.21451993145593365, 'Academic_Performance': -0.4728724968202753, 'Internship_Experience': -0.0512968082259278, 'Extra_Curricular_Score': -0.36869421121625007, 'Communication_Skills': 0.9879141850361585, 'Projects_Completed': 0.5360689705550038}
# ------------------------------------epoch: 800------------------------------------
# 				cost: 32.335654438196656
# b_dict: {'intercept': -0.142099591373635, 'IQ': -0.20322709619820337, 'Prev_Sem_Result': 0.21677929264992063, 'CGPA': 0.254196861057495, 'Academic_Performance': -0.5226964768188413, 'Internship_Experience': -0.05773477508926187, 'Extra_Curricular_Score': -0.4054534613870331, 'Communication_Skills': 1.1284425610595716, 'Projects_Completed': 0.610488913006787}
# ------------------------------------epoch: 900------------------------------------
# 				cost: 44.644666985019356
# b_dict: {'intercept': -0.16129870175443958, 'IQ': -0.33192284962972163, 'Prev_Sem_Result': 0.22939830045539927, 'CGPA': 0.2713584164843264, 'Academic_Performance': -0.5800950544979887, 'Internship_Experience': -0.06524064168157334, 'Extra_Curricular_Score': -0.4484032104328614, 'Communication_Skills': 1.247364125516614, 'Projects_Completed': 0.6744856465721021}
# ------------------------------------epoch: 1000------------------------------------
# 				cost: 34.89446658050354
# b_dict: {'intercept': -0.180268878722953, 'IQ': -0.2351072174720048, 'Prev_Sem_Result': 0.2338319622371135, 'CGPA': 0.2803949286647996, 'Academic_Performance': -0.5889693260222255, 'Internship_Experience': -0.07194110863332265, 'Extra_Curricular_Score': -0.45211771941315726, 'Communication_Skills': 1.2460631442020784, 'Projects_Completed': 0.720175155043539}
# ------------------------------------epoch: 1100------------------------------------
# 				cost: 62.18522765027331
# b_dict: {'intercept': -0.20279626212651936, 'IQ': -0.5037417951150007, 'Prev_Sem_Result': 0.21188382759952892, 'CGPA': 0.2630382699909154, 'Academic_Performance': -0.6169328608487225, 'Internship_Experience': -0.08005164962463501, 'Extra_Curricular_Score': -0.4731245255576544, 'Communication_Skills': 1.232570024510281, 'Projects_Completed': 0.7548898260990397}
# ------------------------------------epoch: 1200------------------------------------
# 				cost: 31.334151857222714
# b_dict: {'intercept': -0.2196681276990789, 'IQ': -0.19939137186184955, 'Prev_Sem_Result': 0.23203236655769455, 'CGPA': 0.28776110956058737, 'Academic_Performance': -0.6095758766840434, 'Internship_Experience': -0.08584157479113899, 'Extra_Curricular_Score': -0.4635029322679799, 'Communication_Skills': 1.2423001769411113, 'Projects_Completed': 0.8006748948477662}
# ------------------------------------epoch: 1300------------------------------------
# 				cost: 0.3993180672525289
# b_dict: {'intercept': -0.24419580029318688, 'IQ': -0.6692606036847087, 'Prev_Sem_Result': 0.19454589055956106, 'CGPA': 0.25483338369589403, 'Academic_Performance': -0.6435882716629853, 'Internship_Experience': -0.09461451552385249, 'Extra_Curricular_Score': -0.49108230400821873, 'Communication_Skills': 1.2140857638897746, 'Projects_Completed': 0.8248549851197731}
# ------------------------------------epoch: 1400------------------------------------
# 				cost: 0.43482027260785033
# b_dict: {'intercept': -0.26474843033453194, 'IQ': -0.6584119406110474, 'Prev_Sem_Result': 0.1848637456527154, 'CGPA': 0.2497669763102549, 'Academic_Performance': -0.6426239984647373, 'Internship_Experience': -0.10178011512658523, 'Extra_Curricular_Score': -0.48791675988258915, 'Communication_Skills': 1.18994532771813, 'Projects_Completed': 0.8516971419405821}
# ------------------------------------epoch: 1500------------------------------------
# 				cost: 8.498175832543415
# b_dict: {'intercept': -0.27857180009554033, 'IQ': -0.021510705613092124, 'Prev_Sem_Result': 0.22733403610587677, 'CGPA': 0.29680977529871355, 'Academic_Performance': -0.6089942919628356, 'Internship_Experience': -0.106230718980251, 'Extra_Curricular_Score': -0.4562244532463475, 'Communication_Skills': 1.212259200942719, 'Projects_Completed': 0.8955958677202531}
# ------------------------------------epoch: 1600------------------------------------
# 				cost: 38.54049659733765
# b_dict: {'intercept': -0.30062149473765254, 'IQ': -0.2683736264898331, 'Prev_Sem_Result': 0.20960879269970217, 'CGPA': 0.2836413330957249, 'Academic_Performance': -0.6293182177225519, 'Internship_Experience': -0.11389691912003128, 'Extra_Curricular_Score': -0.47279303607514567, 'Communication_Skills': 1.2065348630295551, 'Projects_Completed': 0.9209113292518226}
# ------------------------------------epoch: 1700------------------------------------
# 				cost: 8.456399754095168
# b_dict: {'intercept': -0.3186513499849873, 'IQ': -0.022487644139873975, 'Prev_Sem_Result': 0.22001100449753028, 'CGPA': 0.2986470548603696, 'Academic_Performance': -0.6150574898214787, 'Internship_Experience': -0.11998165129484645, 'Extra_Curricular_Score': -0.45844112704026835, 'Communication_Skills': 1.2067490601214448, 'Projects_Completed': 0.9488656392826629}
# ------------------------------------epoch: 1800------------------------------------
# 				cost: 35.134626605081394
# b_dict: {'intercept': -0.3400922646386717, 'IQ': -0.235799250208799, 'Prev_Sem_Result': 0.20838821434600105, 'CGPA': 0.29155714788408743, 'Academic_Performance': -0.6379534803453866, 'Internship_Experience': -0.12747058025459984, 'Extra_Curricular_Score': -0.47676732827838664, 'Communication_Skills': 1.222714361532194, 'Projects_Completed': 0.9757043755573189}
# ------------------------------------epoch: 1900------------------------------------
# 				cost: 2.5663762986867784
# b_dict: {'intercept': -0.36115107774527117, 'IQ': -0.32060440523671874, 'Prev_Sem_Result': 0.19616902476377124, 'CGPA': 0.283896809127153, 'Academic_Performance': -0.6406055200397924, 'Internship_Experience': -0.13455845660367588, 'Extra_Curricular_Score': -0.4789085313123987, 'Communication_Skills': 1.202453536406608, 'Projects_Completed': 0.9934611388276486}
# ------------------------------------epoch: 2000------------------------------------
# 				cost: 11.189576402475947
# b_dict: {'intercept': -0.37766068252565493, 'IQ': -0.01977004922273154, 'Prev_Sem_Result': 0.22102635790061384, 'CGPA': 0.31326763143381153, 'Academic_Performance': -0.6323617577369869, 'Internship_Experience': -0.14000960137930235, 'Extra_Curricular_Score': -0.47013470972186067, 'Communication_Skills': 1.2374989192444446, 'Projects_Completed': 1.028676011901374}
# ------------------------------------epoch: 2100------------------------------------
# 				cost: 3.555660272570289
# b_dict: {'intercept': -0.400065161579592, 'IQ': -0.22816957125197657, 'Prev_Sem_Result': 0.19814728265924975, 'CGPA': 0.2949346218021734, 'Academic_Performance': -0.6394038221311811, 'Internship_Experience': -0.14751088672495435, 'Extra_Curricular_Score': -0.47665748909701317, 'Communication_Skills': 1.204504765270344, 'Projects_Completed': 1.0388667768660131}
# ------------------------------------epoch: 2200------------------------------------
# 				cost: 36.34318460258759
# b_dict: {'intercept': -0.4201862272895542, 'IQ': -0.24649607594982337, 'Prev_Sem_Result': 0.19364372831957347, 'CGPA': 0.29495127302553326, 'Academic_Performance': -0.6388547856753668, 'Internship_Experience': -0.15409759166259746, 'Extra_Curricular_Score': -0.4765467831507796, 'Communication_Skills': 1.1928504631892356, 'Projects_Completed': 1.0559432039984757}
# ------------------------------------epoch: 2300------------------------------------
# 				cost: 21.486187409812928
# b_dict: {'intercept': -0.4390846001837851, 'IQ': -0.09893225491421676, 'Prev_Sem_Result': 0.1969563637759807, 'CGPA': 0.30278947802784795, 'Academic_Performance': -0.6241893412685519, 'Internship_Experience': -0.16012056237311473, 'Extra_Curricular_Score': -0.46401942489571646, 'Communication_Skills': 1.1776370894633768, 'Projects_Completed': 1.0706582614831204}
# ------------------------------------epoch: 2400------------------------------------
# 				cost: 22.849410211983926
# b_dict: {'intercept': -0.459508257482208, 'IQ': -0.11156517429816307, 'Prev_Sem_Result': 0.18978305591162592, 'CGPA': 0.3001613393430918, 'Academic_Performance': -0.6216829797058735, 'Internship_Experience': -0.16680658611591642, 'Extra_Curricular_Score': -0.46159744695938687, 'Communication_Skills': 1.1679867730051845, 'Projects_Completed': 1.081945965554319}
# ------------------------------------epoch: 2500------------------------------------
# 				cost: 8.644187130477398
# b_dict: {'intercept': -0.47892358013796854, 'IQ': -0.018445412316255932, 'Prev_Sem_Result': 0.190527359813056, 'CGPA': 0.30545381498758384, 'Academic_Performance': -0.6137034538802942, 'Internship_Experience': -0.17306952204727327, 'Extra_Curricular_Score': -0.4541980666518665, 'Communication_Skills': 1.166616324720227, 'Projects_Completed': 1.0945403868938903}
# ------------------------------------epoch: 2600------------------------------------
# 				cost: 46.334528330010066
# b_dict: {'intercept': -0.5021991199388814, 'IQ': -0.3421706515601811, 'Prev_Sem_Result': 0.16307619314064695, 'CGPA': 0.28253865288340607, 'Academic_Performance': -0.6315822375534812, 'Internship_Experience': -0.1808422765688275, 'Extra_Curricular_Score': -0.46996071263255895, 'Communication_Skills': 1.1497537005457659, 'Projects_Completed': 1.0991761787168717}
# ------------------------------------epoch: 2700------------------------------------
# 				cost: 0.6990340029599189
# b_dict: {'intercept': -0.5244590916631625, 'IQ': -0.5988744005987245, 'Prev_Sem_Result': 0.14432122593951316, 'CGPA': 0.26829977676025424, 'Academic_Performance': -0.6492463265145074, 'Internship_Experience': -0.18820625899262847, 'Extra_Curricular_Score': -0.48544176253044385, 'Communication_Skills': 1.1464583755792446, 'Projects_Completed': 1.1086288907629955}
# ------------------------------------epoch: 2800------------------------------------
# 				cost: 54.8801307236339
# b_dict: {'intercept': -0.5422895906898201, 'IQ': -0.42848667323651696, 'Prev_Sem_Result': 0.15948649332970297, 'CGPA': 0.2879560917291747, 'Academic_Performance': -0.6463060166755036, 'Internship_Experience': -0.19387077697799443, 'Extra_Curricular_Score': -0.482173754625964, 'Communication_Skills': 1.173849088336582, 'Projects_Completed': 1.1311119202175368}
# ------------------------------------epoch: 2900------------------------------------
# 				cost: 41.527170140830805
# b_dict: {'intercept': -0.5609571286201762, 'IQ': -0.2967586941804301, 'Prev_Sem_Result': 0.1665151399312043, 'CGPA': 0.2994725480702724, 'Academic_Performance': -0.6385429753359577, 'Internship_Experience': -0.19968522969958946, 'Extra_Curricular_Score': -0.47546401964705826, 'Communication_Skills': 1.177275972069479, 'Projects_Completed': 1.1452487821992796}
# ------------------------------------epoch: 3000------------------------------------
# 				cost: 46.383456569666826
# b_dict: {'intercept': -0.5815088447744697, 'IQ': -0.3445991876807141, 'Prev_Sem_Result': 0.15984318009494464, 'CGPA': 0.29730739344025225, 'Academic_Performance': -0.6427546485985001, 'Internship_Experience': -0.2063326192030339, 'Extra_Curricular_Score': -0.4787549157035657, 'Communication_Skills': 1.1786535219811773, 'Projects_Completed': 1.1549264080742512}
# ------------------------------------epoch: 3100------------------------------------
# 				cost: 2.4002388442412883
# b_dict: {'intercept': -0.601871599351105, 'IQ': -0.3357491886489611, 'Prev_Sem_Result': 0.1528466275852379, 'CGPA': 0.2948105089519746, 'Academic_Performance': -0.6362902424120302, 'Internship_Experience': -0.21264219839320156, 'Extra_Curricular_Score': -0.473767515601082, 'Communication_Skills': 1.15928607969305, 'Projects_Completed': 1.1586660333331504}
# ------------------------------------epoch: 3200------------------------------------
# 				cost: 6.4774862424012065
# b_dict: {'intercept': -0.6188816404158224, 'IQ': -0.06743234813282226, 'Prev_Sem_Result': 0.1742313239250257, 'CGPA': 0.3206828994578784, 'Academic_Performance': -0.627344237894634, 'Internship_Experience': -0.21790346079427803, 'Extra_Curricular_Score': -0.4649607244955842, 'Communication_Skills': 1.1923858928193243, 'Projects_Completed': 1.1798049791665204}
# ------------------------------------epoch: 3300------------------------------------
# 				cost: 3.7022486832691786
# b_dict: {'intercept': -0.6409153502515751, 'IQ': -0.20818260879504052, 'Prev_Sem_Result': 0.15387792659937027, 'CGPA': 0.30481861437502, 'Academic_Performance': -0.6250708107393189, 'Internship_Experience': -0.22470223700416267, 'Extra_Curricular_Score': -0.464298288076146, 'Communication_Skills': 1.1541299558711335, 'Projects_Completed': 1.1746182118087563}
# ------------------------------------epoch: 3400------------------------------------
# 				cost: 43.53465451114101
# b_dict: {'intercept': -0.6617609003760228, 'IQ': -0.3145687045742401, 'Prev_Sem_Result': 0.14554567738031224, 'CGPA': 0.30095427038947326, 'Academic_Performance': -0.6321546376510683, 'Internship_Experience': -0.2312644052009476, 'Extra_Curricular_Score': -0.47072727602254205, 'Communication_Skills': 1.1547907921650076, 'Projects_Completed': 1.181203831719407}
# ------------------------------------epoch: 3500------------------------------------
# 				cost: 21.518281826910354
# b_dict: {'intercept': -0.6797434672481841, 'IQ': -0.09739128417824783, 'Prev_Sem_Result': 0.15771887868452067, 'CGPA': 0.3175992140648415, 'Academic_Performance': -0.6179614439312141, 'Internship_Experience': -0.23661688466648495, 'Extra_Curricular_Score': -0.45830508011135157, 'Communication_Skills': 1.1602577544138886, 'Projects_Completed': 1.1913645791131282}
# ------------------------------------epoch: 3600------------------------------------
# 				cost: 1.1432430451880418
# b_dict: {'intercept': -0.7045121520352325, 'IQ': -0.506541697801595, 'Prev_Sem_Result': 0.11660884191113915, 'CGPA': 0.2809716062225542, 'Academic_Performance': -0.6282667326068313, 'Internship_Experience': -0.24432511191113718, 'Extra_Curricular_Score': -0.46914359879902323, 'Communication_Skills': 1.1043009815566773, 'Projects_Completed': 1.1750236336357112}
# ------------------------------------epoch: 3700------------------------------------
# 				cost: 63.11217413730141
# b_dict: {'intercept': -0.7241388359192562, 'IQ': -0.5054631840761021, 'Prev_Sem_Result': 0.11802564980774423, 'CGPA': 0.2868385901593221, 'Academic_Performance': -0.6307502256126362, 'Internship_Experience': -0.2502900666291246, 'Extra_Curricular_Score': -0.47145668853957445, 'Communication_Skills': 1.11589537555311, 'Projects_Completed': 1.1839448120045117}
# ------------------------------------epoch: 3800------------------------------------
# 				cost: 56.57602441803091
# b_dict: {'intercept': -0.7427505125256746, 'IQ': -0.4430862293120377, 'Prev_Sem_Result': 0.1282201420797705, 'CGPA': 0.301469381213166, 'Academic_Performance': -0.635877926763188, 'Internship_Experience': -0.25595957778399, 'Extra_Curricular_Score': -0.4754020663718468, 'Communication_Skills': 1.1467116513224307, 'Projects_Completed': 1.200612352108851}
# ------------------------------------epoch: 3900------------------------------------
# 				cost: 0.31485242898915494
# b_dict: {'intercept': -0.7661984477976019, 'IQ': -0.6873160211403059, 'Prev_Sem_Result': 0.09590298974036027, 'CGPA': 0.27361824999238965, 'Academic_Performance': -0.6344806722256829, 'Internship_Experience': -0.26296654343697573, 'Extra_Curricular_Score': -0.4758978100631767, 'Communication_Skills': 1.0883538613543193, 'Projects_Completed': 1.1834041444071437}
# ------------------------------------epoch: 4000------------------------------------
# 				cost: 16.614633125643724
# b_dict: {'intercept': -0.7800538345565712, 'IQ': -0.047162643828278505, 'Prev_Sem_Result': 0.13957280429720217, 'CGPA': 0.3217514499587061, 'Academic_Performance': -0.5981720127067243, 'Internship_Experience': -0.2665182531318776, 'Extra_Curricular_Score': -0.44336793126976887, 'Communication_Skills': 1.1227023675427235, 'Projects_Completed': 1.2014550607112295}
# ------------------------------------epoch: 4100------------------------------------
# 				cost: 44.60234989266335
# b_dict: {'intercept': -0.8022780023902442, 'IQ': -0.32309037315354816, 'Prev_Sem_Result': 0.12254853554770108, 'CGPA': 0.3091954956840787, 'Academic_Performance': -0.6210739789628303, 'Internship_Experience': -0.27353000628877444, 'Extra_Curricular_Score': -0.46285474104264507, 'Communication_Skills': 1.1340744308449076, 'Projects_Completed': 1.2063066333140353}
# ------------------------------------epoch: 4200------------------------------------
# 				cost: 37.40814800234999
# b_dict: {'intercept': -0.820875126934561, 'IQ': -0.25389909011539913, 'Prev_Sem_Result': 0.13249586320285792, 'CGPA': 0.32354714556758263, 'Academic_Performance': -0.6243847242268109, 'Internship_Experience': -0.2790453176329536, 'Extra_Curricular_Score': -0.4653921084356612, 'Communication_Skills': 1.1599610035693313, 'Projects_Completed': 1.2207648582437531}
# ------------------------------------epoch: 4300------------------------------------
# 				cost: 34.1396837412552
# b_dict: {'intercept': -0.8408089083504116, 'IQ': -0.22072392925686538, 'Prev_Sem_Result': 0.1296098099593655, 'CGPA': 0.32510900673570586, 'Academic_Performance': -0.6195769835854789, 'Internship_Experience': -0.28481772181505743, 'Extra_Curricular_Score': -0.4614134253806006, 'Communication_Skills': 1.1512474681116638, 'Projects_Completed': 1.2218332334777184}
# ------------------------------------epoch: 4400------------------------------------
# 				cost: 5.276631987335372
# b_dict: {'intercept': -0.8600572727821342, 'IQ': -0.10473240828824305, 'Prev_Sem_Result': 0.13169130636300724, 'CGPA': 0.33163653015351274, 'Academic_Performance': -0.609303547775607, 'Internship_Experience': -0.29032345256332737, 'Extra_Curricular_Score': -0.4524396112437511, 'Communication_Skills': 1.1457307338618006, 'Projects_Completed': 1.2231729169428769}
# ------------------------------------epoch: 4500------------------------------------
# 				cost: 0.3205664931932461
# b_dict: {'intercept': -0.8860748296313993, 'IQ': -0.6861782815075801, 'Prev_Sem_Result': 0.08328351392729533, 'CGPA': 0.2876844564933012, 'Academic_Performance': -0.6380546114977562, 'Internship_Experience': -0.29842729505124027, 'Extra_Curricular_Score': -0.47837557452367296, 'Communication_Skills': 1.107043202028379, 'Projects_Completed': 1.207593284790399}
# ------------------------------------epoch: 4600------------------------------------
# 				cost: 0.9292348306347682
# b_dict: {'intercept': -0.9044420507226352, 'IQ': -0.5505096499971212, 'Prev_Sem_Result': 0.09453046877358412, 'CGPA': 0.30337737878062554, 'Academic_Performance': -0.6357992859742652, 'Internship_Experience': -0.30373436561571576, 'Extra_Curricular_Score': -0.4755855392939096, 'Communication_Skills': 1.131065485467075, 'Projects_Completed': 1.2190409616254516}
# ------------------------------------epoch: 4700------------------------------------
# 				cost: 0.3726382003060201
# b_dict: {'intercept': -0.9252258906439075, 'IQ': -0.6748980883522461, 'Prev_Sem_Result': 0.08743091064481914, 'CGPA': 0.3006803732457027, 'Academic_Performance': -0.6469678970940164, 'Internship_Experience': -0.30988850304772925, 'Extra_Curricular_Score': -0.4855625829845107, 'Communication_Skills': 1.1365740677813412, 'Projects_Completed': 1.224522936591904}
# ------------------------------------epoch: 4800------------------------------------
# 				cost: 3.6424598762175577
# b_dict: {'intercept': -0.9408755128508528, 'IQ': -0.21262914282967965, 'Prev_Sem_Result': 0.11693605356350432, 'CGPA': 0.334601304698154, 'Academic_Performance': -0.61826613191659, 'Internship_Experience': -0.3138627993637021, 'Extra_Curricular_Score': -0.46024046216809894, 'Communication_Skills': 1.1516099506116022, 'Projects_Completed': 1.2351846506455575}
# ------------------------------------epoch: 4900------------------------------------
# 				cost: 0.3185726012515226
# b_dict: {'intercept': -0.9658973311170402, 'IQ': -0.6860874253677739, 'Prev_Sem_Result': 0.07481003106460898, 'CGPA': 0.29686355130014636, 'Academic_Performance': -0.6356754200024214, 'Internship_Experience': -0.32126745628940706, 'Extra_Curricular_Score': -0.47727639528840665, 'Communication_Skills': 1.1002158117628258, 'Projects_Completed': 1.2177536766450312}
# ------------------------------------epoch: 5000------------------------------------
# 				cost: 36.00706063407198
# b_dict: {'intercept': -0.9807491086560252, 'IQ': -0.23859710637539178, 'Prev_Sem_Result': 0.11376832651405851, 'CGPA': 0.3402358393446462, 'Academic_Performance': -0.6214083844904426, 'Internship_Experience': -0.325218377738443, 'Extra_Curricular_Score': -0.463095599308239, 'Communication_Skills': 1.1583702415267423, 'Projects_Completed': 1.2420463010995693}
# ------------------------------------epoch: 5100------------------------------------
# 				cost: 1.0567882735284264
# b_dict: {'intercept': -1.0034340694647375, 'IQ': -0.528384386617397, 'Prev_Sem_Result': 0.0910722264909992, 'CGPA': 0.3219167974691509, 'Academic_Performance': -0.637077158500021, 'Internship_Experience': -0.3319236750181158, 'Extra_Curricular_Score': -0.4774436664010887, 'Communication_Skills': 1.1417052718790341, 'Projects_Completed': 1.2377476395568385}
# ------------------------------------epoch: 5200------------------------------------
# 				cost: 0.8750493100890688
# b_dict: {'intercept': -1.0239106102157942, 'IQ': -0.5602466513467026, 'Prev_Sem_Result': 0.083478084659139, 'CGPA': 0.31868310514435527, 'Academic_Performance': -0.632659867456743, 'Internship_Experience': -0.3375086732003592, 'Extra_Curricular_Score': -0.4748074527502861, 'Communication_Skills': 1.1203084851171852, 'Projects_Completed': 1.2337155656527523}
# ------------------------------------epoch: 5300------------------------------------
# 				cost: 29.2273684164999
# b_dict: {'intercept': -1.040190336158836, 'IQ': -0.1698617345650836, 'Prev_Sem_Result': 0.10824768303051577, 'CGPA': 0.34784432778124175, 'Academic_Performance': -0.6090999574118112, 'Internship_Experience': -0.3415437382459092, 'Extra_Curricular_Score': -0.45372655972197296, 'Communication_Skills': 1.1361999994345215, 'Projects_Completed': 1.2424183355283835}
# ------------------------------------epoch: 5400------------------------------------
# 				cost: 6.7109360306473365
# b_dict: {'intercept': -1.0582664197197296, 'IQ': -0.05550163357451468, 'Prev_Sem_Result': 0.12242308950840687, 'CGPA': 0.3663869845344645, 'Academic_Performance': -0.6115377362086796, 'Internship_Experience': -0.34655778387160796, 'Extra_Curricular_Score': -0.45520278886693616, 'Communication_Skills': 1.1698475609187813, 'Projects_Completed': 1.2573386745362705}
# ------------------------------------epoch: 5500------------------------------------
# 				cost: 43.30858161035107
# b_dict: {'intercept': -1.0809570357676987, 'IQ': -0.3095002205812314, 'Prev_Sem_Result': 0.09838333548573504, 'CGPA': 0.34672011642788025, 'Academic_Performance': -0.6219672961716892, 'Internship_Experience': -0.3530480871050415, 'Extra_Curricular_Score': -0.4648314131323138, 'Communication_Skills': 1.1447717762878051, 'Projects_Completed': 1.2488254189863717}
# ------------------------------------epoch: 5600------------------------------------
# 				cost: 63.480792272336885
# b_dict: {'intercept': -1.1033734944955538, 'IQ': -0.5062710260674474, 'Prev_Sem_Result': 0.07528049937972409, 'CGPA': 0.32798349842700647, 'Academic_Performance': -0.6240931841531164, 'Internship_Experience': -0.3592251661805978, 'Extra_Curricular_Score': -0.4677000103858566, 'Communication_Skills': 1.1087266925797248, 'Projects_Completed': 1.2359160150541801}
# ------------------------------------epoch: 5700------------------------------------
# 				cost: 1.4081002859664082
# b_dict: {'intercept': -1.123531932785507, 'IQ': -0.4574429140517741, 'Prev_Sem_Result': 0.06941530674311513, 'CGPA': 0.32651608102394447, 'Academic_Performance': -0.6130185087704696, 'Internship_Experience': -0.36448448571334996, 'Extra_Curricular_Score': -0.4584166815565848, 'Communication_Skills': 1.0892467166488988, 'Projects_Completed': 1.2277520092236072}
# ------------------------------------epoch: 5800------------------------------------
# 				cost: 7.399375135383122
# b_dict: {'intercept': -1.1385333513969762, 'IQ': -0.032986952634599456, 'Prev_Sem_Result': 0.10746296421333269, 'CGPA': 0.3689516455391695, 'Academic_Performance': -0.6009930363897179, 'Internship_Experience': -0.36827844558396367, 'Extra_Curricular_Score': -0.44628984316304726, 'Communication_Skills': 1.1496230882197256, 'Projects_Completed': 1.2513817430542002}
# ------------------------------------epoch: 5900------------------------------------
# 				cost: 31.237302461586758
# b_dict: {'intercept': -1.1594795031241176, 'IQ': -0.19001208653213067, 'Prev_Sem_Result': 0.09874471523964302, 'CGPA': 0.364555593005912, 'Academic_Performance': -0.6120799441725517, 'Internship_Experience': -0.3740569419308691, 'Extra_Curricular_Score': -0.45664487619586663, 'Communication_Skills': 1.1498715464735156, 'Projects_Completed': 1.2533605198383222}
# ------------------------------------epoch: 6000------------------------------------
# 				cost: 3.309557559242918
# b_dict: {'intercept': -1.1795860325358216, 'IQ': -0.24647680661407656, 'Prev_Sem_Result': 0.09709560173532546, 'CGPA': 0.36730741428881547, 'Academic_Performance': -0.6246578530987387, 'Internship_Experience': -0.3797697044315985, 'Extra_Curricular_Score': -0.4662584173569808, 'Communication_Skills': 1.1741160990852313, 'Projects_Completed': 1.2621386333056084}
# ------------------------------------epoch: 6100------------------------------------
# 				cost: 11.41664283651224
# b_dict: {'intercept': -1.1973480922641793, 'IQ': -0.012049732230973331, 'Prev_Sem_Result': 0.11024398245115608, 'CGPA': 0.3847952638618231, 'Academic_Performance': -0.6081911892209596, 'Internship_Experience': -0.3840979998253281, 'Extra_Curricular_Score': -0.45217823112286426, 'Communication_Skills': 1.1743118804927437, 'Projects_Completed': 1.2660060908882411}
# ------------------------------------epoch: 6200------------------------------------
# 				cost: 0.3845821697287564
# b_dict: {'intercept': -1.223743095863933, 'IQ': -0.6702111038745274, 'Prev_Sem_Result': 0.05851646724385404, 'CGPA': 0.33738981012333846, 'Academic_Performance': -0.6411466552651598, 'Internship_Experience': -0.3918090415202686, 'Extra_Curricular_Score': -0.4823885552850772, 'Communication_Skills': 1.1285512045845607, 'Projects_Completed': 1.2486556784144582}
# ------------------------------------epoch: 6300------------------------------------
# 				cost: 36.27128249404243
# b_dict: {'intercept': -1.2392570048184308, 'IQ': -0.2393313289343171, 'Prev_Sem_Result': 0.08919811124761447, 'CGPA': 0.3723828731325684, 'Academic_Performance': -0.616641971140064, 'Internship_Experience': -0.39528972196988227, 'Extra_Curricular_Score': -0.46076874886337443, 'Communication_Skills': 1.1500774963209166, 'Projects_Completed': 1.2604385277980161}
# ------------------------------------epoch: 6400------------------------------------
# 				cost: 4.964552582903661
# b_dict: {'intercept': -1.2578332791288518, 'IQ': -0.12532890423314913, 'Prev_Sem_Result': 0.09752823027932381, 'CGPA': 0.3850495689250758, 'Academic_Performance': -0.6133221380319357, 'Internship_Experience': -0.4000836941034468, 'Extra_Curricular_Score': -0.45727599843958006, 'Communication_Skills': 1.1651611256255936, 'Projects_Completed': 1.2674359930562271}
# ------------------------------------epoch: 6500------------------------------------
# 				cost: 44.82345896943494
# b_dict: {'intercept': -1.2797801669521953, 'IQ': -0.3234490984500682, 'Prev_Sem_Result': 0.07940120139968498, 'CGPA': 0.3712478781278917, 'Academic_Performance': -0.6223950261137122, 'Internship_Experience': -0.40602050615947494, 'Extra_Curricular_Score': -0.4655664046962417, 'Communication_Skills': 1.1492337221878406, 'Projects_Completed': 1.2615429807665748}
# ------------------------------------epoch: 6600------------------------------------
# 				cost: 22.26042696879516
# b_dict: {'intercept': -1.2975236617048613, 'IQ': -0.10072561651306139, 'Prev_Sem_Result': 0.09272780706612888, 'CGPA': 0.38888562681015165, 'Academic_Performance': -0.6072635517463288, 'Internship_Experience': -0.41022063801715875, 'Extra_Curricular_Score': -0.4524331243803142, 'Communication_Skills': 1.1533679771048488, 'Projects_Completed': 1.265395001347632}
# ------------------------------------epoch: 6700------------------------------------
# 				cost: 39.12936062226578
# b_dict: {'intercept': -1.3191376066723295, 'IQ': -0.2664438019595088, 'Prev_Sem_Result': 0.0772293762539309, 'CGPA': 0.37773052443548655, 'Academic_Performance': -0.6152396711472183, 'Internship_Experience': -0.4159390902414457, 'Extra_Curricular_Score': -0.45956939786860423, 'Communication_Skills': 1.143628683779558, 'Projects_Completed': 1.260023483286097}
# ------------------------------------epoch: 6800------------------------------------
# 				cost: 23.081385474178894
# b_dict: {'intercept': -1.3371643403284306, 'IQ': -0.10889553686410436, 'Prev_Sem_Result': 0.08954189335749128, 'CGPA': 0.3943378261176861, 'Academic_Performance': -0.6081150713180513, 'Internship_Experience': -0.4203425099777667, 'Extra_Curricular_Score': -0.45331639783201083, 'Communication_Skills': 1.1582341361196233, 'Projects_Completed': 1.2672501343253688}
# ------------------------------------epoch: 6900------------------------------------
# 				cost: 1.6489623479777704
# b_dict: {'intercept': -1.3599012094143454, 'IQ': -0.4322999201782516, 'Prev_Sem_Result': 0.06680379855026855, 'CGPA': 0.3759107623227964, 'Academic_Performance': -0.6297679153766115, 'Internship_Experience': -0.42666994470909353, 'Extra_Curricular_Score': -0.4723030324030594, 'Communication_Skills': 1.1530127276635396, 'Projects_Completed': 1.2645168805336402}
# ------------------------------------epoch: 7000------------------------------------
# 				cost: 4.880101938185835
# b_dict: {'intercept': -1.3769544949442036, 'IQ': -0.12719938831012909, 'Prev_Sem_Result': 0.08467990157786393, 'CGPA': 0.3980728591073917, 'Academic_Performance': -0.6091720657168741, 'Internship_Experience': -0.4304651438231881, 'Extra_Curricular_Score': -0.45441186782569065, 'Communication_Skills': 1.1567700753192598, 'Projects_Completed': 1.2689491315820098}
# ------------------------------------epoch: 7100------------------------------------
# 				cost: 1.2028753670087975
# b_dict: {'intercept': -1.4005876013184617, 'IQ': -0.49822471748349684, 'Prev_Sem_Result': 0.05313163784048277, 'CGPA': 0.3708022386360627, 'Academic_Performance': -0.6248274998711065, 'Internship_Experience': -0.4367583781078762, 'Extra_Curricular_Score': -0.46917980098509876, 'Communication_Skills': 1.1242881181595787, 'Projects_Completed': 1.2558059597644027}
# ------------------------------------epoch: 7200------------------------------------
# 				cost: 0.35942072145200943
# b_dict: {'intercept': -1.421836406373098, 'IQ': -0.6756931217735231, 'Prev_Sem_Result': 0.04134527889862861, 'CGPA': 0.3633075516470191, 'Academic_Performance': -0.63826307919276, 'Internship_Experience': -0.44241147429671235, 'Extra_Curricular_Score': -0.48077261646481334, 'Communication_Skills': 1.1270051534538639, 'Projects_Completed': 1.25633797804392}
# ------------------------------------epoch: 7300------------------------------------
# 				cost: 1.2061520484483284
# b_dict: {'intercept': -1.4398569949373472, 'IQ': -0.5000600813833155, 'Prev_Sem_Result': 0.0529936253502698, 'CGPA': 0.379237600824917, 'Academic_Performance': -0.629758388846476, 'Internship_Experience': -0.4467010374127434, 'Extra_Curricular_Score': -0.47305488760508557, 'Communication_Skills': 1.1393285714574581, 'Projects_Completed': 1.2626054388627785}
# ------------------------------------epoch: 7400------------------------------------
# 				cost: 0.4087020069556079
# b_dict: {'intercept': -1.4610725983465351, 'IQ': -0.6637951475158963, 'Prev_Sem_Result': 0.0407282741192351, 'CGPA': 0.3712412172587967, 'Academic_Performance': -0.6401546009936852, 'Internship_Experience': -0.45217255258576056, 'Extra_Curricular_Score': -0.48243207209708094, 'Communication_Skills': 1.133921072207285, 'Projects_Completed': 1.2615413955203205}
# ------------------------------------epoch: 7500------------------------------------
# 				cost: 11.496492260858766
# b_dict: {'intercept': -1.4747579524607926, 'IQ': -0.007966878239777903, 'Prev_Sem_Result': 0.08279280476685771, 'CGPA': 0.41754118990525074, 'Academic_Performance': -0.5958758425305858, 'Internship_Experience': -0.4542958282012942, 'Extra_Curricular_Score': -0.4440155416518751, 'Communication_Skills': 1.1457836521317613, 'Projects_Completed': 1.2700658933947788}
# ------------------------------------epoch: 7600------------------------------------
# 				cost: 3.397938968257002
# b_dict: {'intercept': -1.4966096639281907, 'IQ': -0.22902071012623962, 'Prev_Sem_Result': 0.06568568369029969, 'CGPA': 0.404711752491001, 'Academic_Performance': -0.609613220279768, 'Internship_Experience': -0.4599408022451111, 'Extra_Curricular_Score': -0.45609876641794644, 'Communication_Skills': 1.1402322054220384, 'Projects_Completed': 1.2665480611250577}
# ------------------------------------epoch: 7700------------------------------------
# 				cost: 26.304355347549407
# b_dict: {'intercept': -1.51554361316092, 'IQ': -0.13878835756449193, 'Prev_Sem_Result': 0.069865822258757, 'CGPA': 0.4131566202355058, 'Academic_Performance': -0.6042731190772812, 'Internship_Experience': -0.46435772658327257, 'Extra_Curricular_Score': -0.451294660067882, 'Communication_Skills': 1.1448812948422933, 'Projects_Completed': 1.268428763913149}
# ------------------------------------epoch: 7800------------------------------------
# 				cost: 1.180130970001469
# b_dict: {'intercept': -1.538592554996811, 'IQ': -0.5046412517253532, 'Prev_Sem_Result': 0.04467439516901973, 'CGPA': 0.3922442385245386, 'Academic_Performance': -0.6295355020847553, 'Internship_Experience': -0.47058865153833074, 'Extra_Curricular_Score': -0.47311890662783096, 'Communication_Skills': 1.1428169052722426, 'Projects_Completed': 1.2651775057011396}
# ------------------------------------epoch: 7900------------------------------------
# 				cost: 34.714177752056
# b_dict: {'intercept': -1.556094003242564, 'IQ': -0.22087534843060092, 'Prev_Sem_Result': 0.057821915000963967, 'CGPA': 0.40963511693359944, 'Academic_Performance': -0.606000602501444, 'Internship_Experience': -0.47414352042032865, 'Extra_Curricular_Score': -0.4529305806746804, 'Communication_Skills': 1.1356053677040632, 'Projects_Completed': 1.2635006163712217}
# ------------------------------------epoch: 8000------------------------------------
# 				cost: 41.43130222598477
# b_dict: {'intercept': -1.5762618361764338, 'IQ': -0.28780517134409067, 'Prev_Sem_Result': 0.054008212671328354, 'CGPA': 0.4100817788027959, 'Academic_Performance': -0.6134678281443265, 'Internship_Experience': -0.47914727360423437, 'Extra_Curricular_Score': -0.4591072922518046, 'Communication_Skills': 1.1451680407694749, 'Projects_Completed': 1.266274742063131}
# ------------------------------------epoch: 8100------------------------------------
# 				cost: 32.22763592621369
# b_dict: {'intercept': -1.5950550701020192, 'IQ': -0.1973152561318374, 'Prev_Sem_Result': 0.05979398284610628, 'CGPA': 0.42013012715583775, 'Academic_Performance': -0.6099508172937822, 'Internship_Experience': -0.48349305984450086, 'Extra_Curricular_Score': -0.45566633132795464, 'Communication_Skills': 1.1554613105708207, 'Projects_Completed': 1.2701760992533921}
# ------------------------------------epoch: 8200------------------------------------
# 				cost: 37.56658973094139
# b_dict: {'intercept': -1.6150231202390326, 'IQ': -0.2507553231392634, 'Prev_Sem_Result': 0.05761094000401716, 'CGPA': 0.4222040926541993, 'Academic_Performance': -0.6177961589174679, 'Internship_Experience': -0.488386641507072, 'Extra_Curricular_Score': -0.46220821809131246, 'Communication_Skills': 1.1669235289777606, 'Projects_Completed': 1.2749013358189705}
# ------------------------------------epoch: 8300------------------------------------
# 				cost: 0.37844159486251594
# b_dict: {'intercept': -1.6390039471915454, 'IQ': -0.6701044121391979, 'Prev_Sem_Result': 0.023131796605010697, 'CGPA': 0.39194621522943773, 'Academic_Performance': -0.6379553998085834, 'Internship_Experience': -0.4945696357144299, 'Extra_Curricular_Score': -0.4807895995233874, 'Communication_Skills': 1.1339542588812892, 'Projects_Completed': 1.2626386220285961}
# ------------------------------------epoch: 8400------------------------------------
# 				cost: 4.302530953601891
# b_dict: {'intercept': -1.6532531735373257, 'IQ': -0.16856578417402207, 'Prev_Sem_Result': 0.06443548360493703, 'CGPA': 0.4374762242281978, 'Academic_Performance': -0.6170783309576614, 'Internship_Experience': -0.49728782503806435, 'Extra_Curricular_Score': -0.46145762236701526, 'Communication_Skills': 1.1815382474877825, 'Projects_Completed': 1.28386264275322}
# ------------------------------------epoch: 8500------------------------------------
# 				cost: 43.92893752853837
# b_dict: {'intercept': -1.6753899123597689, 'IQ': -0.3110780905262496, 'Prev_Sem_Result': 0.041073985107219525, 'CGPA': 0.4183524695069905, 'Academic_Performance': -0.6137965700401924, 'Internship_Experience': -0.5024122163545014, 'Extra_Curricular_Score': -0.4594242201606429, 'Communication_Skills': 1.1383662822627223, 'Projects_Completed': 1.267115521698561}
# ------------------------------------epoch: 8600------------------------------------
# 				cost: 61.611606215535815
# b_dict: {'intercept': -1.6964399033840833, 'IQ': -0.4867931504340225, 'Prev_Sem_Result': 0.031446922064742026, 'CGPA': 0.4129898377059412, 'Academic_Performance': -0.6309035100207531, 'Internship_Experience': -0.5078140941444119, 'Extra_Curricular_Score': -0.47346273604551703, 'Communication_Skills': 1.1540637991739449, 'Projects_Completed': 1.2709013386893944}
# ------------------------------------epoch: 8700------------------------------------
# 				cost: 24.44419957063882
# b_dict: {'intercept': -1.7126628800229886, 'IQ': -0.1201259178126649, 'Prev_Sem_Result': 0.05540359332600896, 'CGPA': 0.44115517100566076, 'Academic_Performance': -0.6082522605284997, 'Internship_Experience': -0.5108883851380908, 'Extra_Curricular_Score': -0.45358464025589657, 'Communication_Skills': 1.1671812310832583, 'Projects_Completed': 1.2780977970072451}
# ------------------------------------epoch: 8800------------------------------------
# 				cost: 20.961595788932048
# b_dict: {'intercept': -1.7320381106318439, 'IQ': -0.08572507568412518, 'Prev_Sem_Result': 0.05608704184593817, 'CGPA': 0.44604690626857657, 'Academic_Performance': -0.6050170144480257, 'Internship_Experience': -0.5151823562372476, 'Extra_Curricular_Score': -0.45113737349662064, 'Communication_Skills': 1.1650369626052979, 'Projects_Completed': 1.2787626197643176}
# ------------------------------------epoch: 8900------------------------------------
# 				cost: 21.165452895387816
# b_dict: {'intercept': -1.751477958485882, 'IQ': -0.08863556906716921, 'Prev_Sem_Result': 0.057598026777581315, 'CGPA': 0.45178856791930216, 'Academic_Performance': -0.6098963665751611, 'Internship_Experience': -0.5197509806101308, 'Extra_Curricular_Score': -0.4548397141361429, 'Communication_Skills': 1.1801104435374852, 'Projects_Completed': 1.2843861584912162}
# ------------------------------------epoch: 9000------------------------------------
# 				cost: 41.17476751629751
# b_dict: {'intercept': -1.7732622171995394, 'IQ': -0.2846249513836413, 'Prev_Sem_Result': 0.039180717086981544, 'CGPA': 0.4375605551802805, 'Academic_Performance': -0.6163047873177003, 'Internship_Experience': -0.5248461973001144, 'Extra_Curricular_Score': -0.4614067086483328, 'Communication_Skills': 1.156417697925512, 'Projects_Completed': 1.2760858534129256}
# ------------------------------------epoch: 9100------------------------------------
# 				cost: 27.01100928474312
# b_dict: {'intercept': -1.7916829651183561, 'IQ': -0.14456207158090836, 'Prev_Sem_Result': 0.04644862128347335, 'CGPA': 0.4490217186338792, 'Academic_Performance': -0.6066585104255071, 'Internship_Experience': -0.5286880567487646, 'Extra_Curricular_Score': -0.4531138062515122, 'Communication_Skills': 1.15819152479847, 'Projects_Completed': 1.2780710641247373}
# ------------------------------------epoch: 9200------------------------------------
# 				cost: 5.401810206106945
# b_dict: {'intercept': -1.8107526766181752, 'IQ': -0.10106622461714491, 'Prev_Sem_Result': 0.05039976141168061, 'CGPA': 0.45719720655590534, 'Academic_Performance': -0.6081956355132827, 'Internship_Experience': -0.5329772402838893, 'Extra_Curricular_Score': -0.4539001781733477, 'Communication_Skills': 1.1738426551233034, 'Projects_Completed': 1.2834715793986196}
# ------------------------------------epoch: 9300------------------------------------
# 				cost: 40.43998283854782
# b_dict: {'intercept': -1.8321495484198964, 'IQ': -0.27766514150702903, 'Prev_Sem_Result': 0.036115676009009466, 'CGPA': 0.44713119744720314, 'Academic_Performance': -0.6193968985324371, 'Internship_Experience': -0.5380899215110037, 'Extra_Curricular_Score': -0.4635459449069515, 'Communication_Skills': 1.169636582701379, 'Projects_Completed': 1.2808155178425749}
# ------------------------------------epoch: 9400------------------------------------
# 				cost: 34.66036138428269
# b_dict: {'intercept': -1.8511391831785247, 'IQ': -0.22094781904093086, 'Prev_Sem_Result': 0.040177287039708076, 'CGPA': 0.4553807022398323, 'Academic_Performance': -0.6181091781537713, 'Internship_Experience': -0.5422313183759618, 'Extra_Curricular_Score': -0.46249550886710766, 'Communication_Skills': 1.1771678655218811, 'Projects_Completed': 1.2853803021723993}
# ------------------------------------epoch: 9500------------------------------------
# 				cost: 6.798520494036339
# b_dict: {'intercept': -1.8693409298884414, 'IQ': -0.04835743283678409, 'Prev_Sem_Result': 0.0485786418471602, 'CGPA': 0.4679481611026417, 'Academic_Performance': -0.6046642244092345, 'Internship_Experience': -0.5458380447065903, 'Extra_Curricular_Score': -0.4510722021419429, 'Communication_Skills': 1.1741957588989491, 'Projects_Completed': 1.286314966162903}
# ------------------------------------epoch: 9600------------------------------------
# 				cost: 24.644611544669697
# b_dict: {'intercept': -1.8899417243782155, 'IQ': -0.12021929434458617, 'Prev_Sem_Result': 0.03844829341348698, 'CGPA': 0.4619610261108718, 'Academic_Performance': -0.6021536714863687, 'Internship_Experience': -0.5502107226206794, 'Extra_Curricular_Score': -0.44995171419794755, 'Communication_Skills': 1.152806967183649, 'Projects_Completed': 1.2787843165784702}
# ------------------------------------epoch: 9700------------------------------------
# 				cost: 5.796118771394702
# b_dict: {'intercept': -1.909251882948875, 'IQ': -0.07603123431819966, 'Prev_Sem_Result': 0.03854522127774962, 'CGPA': 0.4661944581531338, 'Academic_Performance': -0.5952086018311483, 'Internship_Experience': -0.5541204618712005, 'Extra_Curricular_Score': -0.4445186173449217, 'Communication_Skills': 1.1454859068117735, 'Projects_Completed': 1.2758266028206886}
# ------------------------------------epoch: 9800------------------------------------
# 				cost: 43.20451982794418
# b_dict: {'intercept': -1.930422053674812, 'IQ': -0.30498302201715327, 'Prev_Sem_Result': 0.028718548392391175, 'CGPA': 0.4605928794807311, 'Academic_Performance': -0.6207354249053844, 'Internship_Experience': -0.5594604375430833, 'Extra_Curricular_Score': -0.4654909779035392, 'Communication_Skills': 1.1737933415581883, 'Projects_Completed': 1.2839519712784149}
# ------------------------------------epoch: 9900------------------------------------
# 				cost: 6.615844985093458
# b_dict: {'intercept': -1.9474167806649236, 'IQ': -0.05721560035017084, 'Prev_Sem_Result': 0.047330064571271924, 'CGPA': 0.48334148656570614, 'Academic_Performance': -0.6084522805500221, 'Internship_Experience': -0.5626818136396553, 'Extra_Curricular_Score': -0.45471071770639554, 'Communication_Skills': 1.1900058455713851, 'Projects_Completed': 1.2930400996242057}
# ------------------------------------epoch: 9999------------------------------------
# 				cost: 7.24926621834978
# b_dict: {'intercept': -1.9670817395343905, 'IQ': -0.03652770221636774, 'Prev_Sem_Result': 0.04221032691616362, 'CGPA': 0.48233097773876166, 'Academic_Performance': -0.6024719249522699, 'Internship_Experience': -0.5667326743180272, 'Extra_Curricular_Score': -0.44977698987830445, 'Communication_Skills': 1.1742592709677213, 'Projects_Completed': 1.2882096204435027}
# final values:
# intercept: -1.96708174
# IQ: -0.0365277
# Prev_Sem_Result: 0.04221033
# CGPA: 0.48233098
# Academic_Performance: -0.60247192
# Internship_Experience: -0.56673267
# Extra_Curricular_Score: -0.44977699
# Communication_Skills: 1.17425927
# Projects_Completed: 1.28820962

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as api
import statsmodels

df = pd.read_csv("./CollegePlacement.csv")
# df = pd.read_csv("./college_partial.csv")

df['Placement'] = pd.factorize(df['Placement'])[0]
df['Internship_Experience'] = pd.factorize(df['Internship_Experience'])[0]

df = df.drop(["College_ID"], axis = 1)
# Y = df["Placement"]

df_with_intercept = statsmodels.tools.tools.add_constant(df, prepend=True)
model = api.logit(formula="Placement ~ IQ + Prev_Sem_Result + CGPA + Academic_Performance + Internship_Experience + Extra_Curricular_Score + Communication_Skills + Projects_Completed", data = df_with_intercept)

model.fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.218626
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Placement   No. Observations:                10000
# Model:                          Logit   Df Residuals:                     9991
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 29 Sep 2025   Pseudo R-squ.:                  0.5134
# Time:                        10:09:18   Log-Likelihood:                -2186.3
# converged:                       True   LL-Null:                       -4493.3
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                -29.1898      0.733    -39.843      0.000     -30.626     -27.754
# IQ                         0.1088      0.004     31.003      0.000       0.102       0.116
# Prev_Sem_Result            0.2072      0.137      1.508      0.131      -0.062       0.477
# CGPA                       1.0505      0.137      7.642      0.000       0.781       1.320
# Academic_Performance      -0.0066      0.013     -0.494      0.621      -0.033       0.020
# Internship_Experience      0.0383      0.079      0.484      0.628      -0.117       0.193
# Extra_Curricular_Score    -0.0160      0.012     -1.311      0.190      -0.040       0.008
# Communication_Skills       0.6481      0.019     33.287      0.000       0.610       0.686
# Projects_Completed         0.6794      0.027     25.044      0.000       0.626       0.733
# ==========================================================================================
# """

# %% [markdown]
# coefficent: {'IQ': 0.1088480546249706, 'Prev_Sem_Result': 0.20739706715685027, 'CGPA': 1.0503634055233622, 'Academic_Performance': -0.006580066792577768, 'Internship_Experience': 0.03812121633450414, 'Extra_Curricular_Score': -0.01601374794054621, 'Communication_Skills': 0.6480372982054753, 'Projects_Completed': 0.6793231551407346}
# intercept: [-29.18952604]

# %%
np.set_printoptions(threshold=np.inf)
# probs = sigmoid(X_with_intercept @ B)
# print("Predicted probabilities:", probs)

# %% [markdown]
# ```python
# array_x = [[1, 1, 4, 7],
#            [1, 2, 5, 8],
#            [1, 3, 6, 9]]
#
# B_array = [1, 1, 1, 1] # b0, b1, b2, b3 all equal 1
#
# array_x * B_array =
# [1, 1, 4, 7] * [b0, b1, b2, b3] = [1 * b0, 1 * b1, 4 * b2, 7 * b3]
# [1, 2, 5, 8] * [b0, b1, b2, b3] = [1 * b0, 2 * b1, 6 * b2, 8 * b3]
# [1, 3, 6, 9] * [b0, b1, b2, b3] = [1 * b0, 3 * b1, 5 * b2, 9 * b3]
#
# ## Lets say b0, b1, b2, b3 all equal 1
# ## This computes B^T*x
# ## These are by z_values
# np.sum(array_x * B_array, axis = 1) = [sum([1 * b0, 1 * b1, 4 * b2, 7 * b3]),
#                                       sum([1 * b0, 2 * b1, 6 * b2, 8 * b3]),
#                                       sum([1 * b0, 3 * b1, 5 * b2, 9 * b3])]
#
#                                     = [13, 17, 18]
#
#
# ```
